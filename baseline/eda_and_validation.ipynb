# %% [markdown]
# EDA findings
#
# - Only 0.16125 of respondants were given a label of 3 or higher.

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import math

# %%
train = pd.read_csv('../data/baseline.csv')
label_counts = train['Label'].value_counts()
predicted_labels = train['Prediction'].value_counts()

combined_counts = pd.DataFrame({
    'Label': label_counts,
    'Prediction': predicted_labels
}).fillna(0)

combined_counts['Label'] = combined_counts['Label'] / combined_counts['Label'].sum()
combined_counts['Prediction'] = combined_counts['Prediction'] / combined_counts['Prediction'].sum()

ax = combined_counts.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Labels')
plt.ylabel('Probability')
plt.title('Label and Prediction Probabilities')

for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# %%
train = pd.read_csv('../data/baseline.csv')
label_counts = train['Label'].value_counts()
counts = label_counts.to_dict()

# create a prior
total = sum(counts.values())
prior = {label: count / total for label, count in sorted(counts.items(), key=lambda item: item[0])}
print(prior)

# visualize the prior
labels = list(prior.keys())
values = list(prior.values())

def plot_vals(labels, values):
    plt.figure(figsize=(10, 6))
    bars = plt.bar(labels, values, color='skyblue')
    plt.xlabel('labels')
    plt.ylabel('prior prob')
    plt.title('priors on train data')

    # label the bars with the probabilities
    for bar, value in zip(bars, values):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}', ha='center', va='bottom')
        
    return plt

plot_vals(labels, values).show()
# Out:
# {1: 0.355, 2: 0.48375, 3: 0.0975, 4: 0.0575, 5: 0.00625}

# %%
mismatched_rows = train[train['Label'] != train['Prediction']][['Input Text','Label', 'Prediction']].sort_values(by='Label', ascending=True)

print("Mismatched Rows:")
mismatched_rows.head(20)

mismatched_rows.to_csv('../data/mismatched_rows.csv')
# Out:
# Mismatched Rows:

# %%
label_1_entries = train[train['Label'] == 1]
print("Entries with Label 1:")
print(label_1_entries)

label_1_entries.to_csv('../data/label_1_entries.csv', index=False)
# Out:
# Entries with Label 1:
#      Unnamed: 0.1  Unnamed: 0  \
# 4               4           4
# 5               5           5
# 6               6           6
# 10             10          10
# 11             11          11
# ..            ...         ...
# 791           791         791
# 792           792         792
# 794           794         794
# 795           795         795
# 798           798         798
#
#                                             Input Text  Label  \
# 4    Interviewer: Thanks for taking the time to int...      1
# 5    Interviewer: It seems like you were about to p...      1
# 6    Interviewer: Great! I see from your applicatio...      1
# 10   Interviewer: Certainly. When you were incorpor...      1
# 11   Interviewer: Thanks for taking the time to int...      1
# ..                                                 ...    ...
# 791  Interviewer: I understand, no problem. Let's p...      1
# 792  Interviewer: Navigating the complexity of defi...      1
# 794  Interviewer: Apologies for the interruption, b...      1
# 795  Interviewer: Thanks for taking the time to int...      1
# 798  Interviewer: Prioritizing frameworks with robu...      1
#
#                                               Question  \
# 4    Thanks for taking the time to interview with u...
# 5    It seems like you were about to provide an exa...
# 6    Great! I see from your application that you ha...
# 10   Certainly. When you were incorporating recent ...
# 11   Thanks for taking the time to interview with u...
# ..                                                 ...
# 791  I understand, no problem. Let's pivot a bit. C...
# 792  Navigating the complexity of defining routes, ...
# 794  Apologies for the interruption, but could you ...
# 795  Thanks for taking the time to interview with u...
# 798  Prioritizing frameworks with robust documentat...
#
#                                               Response  Prediction
# 4                                                  NaN           1
# 5                                    a custom callback           3
# 6    So I have worked on many projects where I have...           2
# 10   Actually at that time it was actually three ye...           2
# 11                                                 NaN           1
# ..                                                 ...         ...
# 791  In deep learning is an upgraded version of mac...           1
# 792  A defining a defining a particular API route f...           2
# 794  Eh. And I would like to recall for any give me...           1
# 795                                                NaN           1
# 798  So like whenever we have any error, like we ca...           2
#
# [284 rows x 7 columns]

# %%
label_1_entries["Response"]
# Out:
# 4                                                    NaN
# 5                                      a custom callback
# 6      So I have worked on many projects where I have...
# 10     Actually at that time it was actually three ye...
# 11                                                   NaN
#                              ...
# 791    In deep learning is an upgraded version of mac...
# 792    A defining a defining a particular API route f...
# 794    Eh. And I would like to recall for any give me...
# 795                                                  NaN
# 798    So like whenever we have any error, like we ca...
# Name: Response, Length: 284, dtype: object

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import math
from tagger import Tagger

labelled = pd.read_csv('../data/baseline.csv')
# small_labelled = labelled[:130]
tagger = Tagger()
res = tagger.apply_function_to_df(labelled, tagger.llm_valid_response, col_name="Valid")

# %%
count = 1
for text in res[(res["Valid"] == True) & (res["Label"] == 1)]["Response"]:
    print(text)
    print(count)
    count+=1
# Out:
# a custom callback
# 1
# So I have worked on many projects where I have used python so you can in my resume you can see my Publications. So all of my Publications the code I wrote was in Python and in technical projects also, you can see three projects and all the three projects are implemented in Python long language and for for practicing data structures and algorithms and for participating in competitive programming I C plus plus has my language for coding. So you see plus plus for combative programming and python for development of applications.
# 2
# Actually at that time it was actually three years ago. My internship was a three years ago. So at that time we didn't have and we were at a very base level of startup. So we didn't have like the much more data to like evaluate or two filter out the noise from so we had a very compact data and we had to use all the data actually and it was select the data selected by the human experts so we didn't have to worry about the noise actually. So that's the thing.
# 3
# So we have utilized the, APIs endpoints and, the controllers we have as mentioned, have user risk controllers and the services are specifically, given the business, things capsulated between them, and we wrote the controllers that accept the, request given by the clients and the the response can be the controllers make use of the services, and then they will be, giving the, response to the client.
# 4
# Yeah one issue was the age inconsistency and the other one was. inconsistencies regarding to
# 5
# Oh, I handled this by modifying my different different apis, for example, whether then rather than going to I implemented a exact path in react chairs. Well, the air was to I have to go to a particular path but a sub part of that URL was already in my room. So what it was going on. It was first going to that route respective of my complete your so I encountered that using exact path and regarding, you know performing my that so rather than using multiple files. Are you break my code into components in the reactants. So basically I was using the same piece of gold again and again, and I also go to which it was taking very few times to load that application and also using direct it's a single page application. So user not have to wait as a question will not reload each time and I used different books like You said you should. In my application to show that you know, whenever application engineer who refreshed can be refreshed on doing another business particular task.
# 6
# Oh, I'm not work on Docker security. But yeah, when I push my images to Docker Hub, I keep in mind that my login ID and password are not shared with any inappropriate user. So that's the only security I used. Also. I have also used some security security purpose in my application. For example in my project in my nodejs project. What I've done is I have used a key and I have put them in a DOT EnV file. So that cannot be patched know from application since I put them in file. So security is provided in my application. Oh, yeah.
# 7
# Okay, so my specialization. I wanted to work on some NLP and machine learning projects because I started with that and from that I chose some little high projects which vary I can just improve my skills. So I just started with image recognition. Then I went for large data sets where I was managing large that us and some other projects like Clash of Education of NLP, like what it is image sound or, you know, some verbal things like that. I just started with my projects and I kept on doing and like almost time doing now, so I'm learning. Thank you.
# 8
# so techniques like I would debug my code and whatever is input according to that what I need output whether it is correct or not. If it is leaving correct output or expected output or approximate output. Then I will consider it is working fine. If it is not giving I'll have to recheck and go through the libraries or what is the error it can give probability. I can just think of it and I can work again on that. Thank you.
# 9
# Should the it's very easy to create a custom loss function pytorch because by General when you do anything with tensors you change them by default. So savior creating a very simple loss function just gives a difference right so you just to Define The functional functions name, so let's never lost. two inputs A and B now, we just need to find the loss between a and b and let's say we're doing a very simple loss is just a difference between a and b what we do is just return minus B. And in this case, it does same as now we have to make sure that NBA about tensors. for this tool because only if their tensors will record and will change the tenses together. So when you use lost or backwards it will so for this example lost function loss A. It just takes a comma BS important and the output is returned a minus B, which is a very simple loss function. We're not going for just for example And it turns the difference between them as the loss function. So once you have that you can just use lost a backwards back propagate on it. Later on.
# 10
# I mean scalar provided me with a bunch of resources to help the students, but for visualizing I mainly relied on hand on techniques because it was a video one-on-one video call. So I would just rip out my whiteboard and I would draw in my laptop and I will show them by compared exactly. What's up.
# 11
# Ah, yeah blind assistance using ml was so small project. I mean to say initially we got the data. I mean in image formats, so we called the Kokomo model with which is a good sense of model, which identifies what kind of object the image as So we tested for various images the Kokomo model gives where the object is present in particular image. I mean in the exact whether it is at the top left corner top right corner bottom right corner bottom left corner bottom center. So we will have the exact location of the object where it will be present by Como model. So we implemented we use your model to identify those along with models so that whenever object is being identified in the image. So we will get the Voice output which helps us a feedback for the blind people. So the video input or the Final End which the user sees in the camera or something will be converted to image and each image will be processed and then we will get the voice feedback. This is all the project works.
# 12
# making indexing far clearer.
# 13
# Yeah, I used of flowers very like I did not walk that much on flash. I used I make made my own only one API by using that because most of the models in my company were going to use going to integrate in a mobile device. So we gave the TF Lite model for the to them to the Android team. So we don't need to make any API for that.
# 14
# So for the prompting might is a common way in hacking facets itself for a rag retrieval augmented Edition. They have generated a like static prompt and we are going to use the particular prompt and the question and the context in hugging faces itself. We can able to generate a data set from the given document. So it this AI will generate the question and answer for the given document. It will act as a data set for for the fine-tuning the model.
# 15
# Ah, no to be honest. Like I have only worked on Google Cloud platform. I I haven't worked on AWS.
# 16
# Hi in the particular project. I have it used any other techniques to ensure that but right now in Gemini and all other GPT models they have also included the any harassment or some some other later which which meant to be in illegal is that generative model can able to predict it and it won't able to process that so in the particular project, I didn't put any any of the butt in I have noted that in upcoming future projects. I will implement.
# 17
# So the normalization techniques as I mentioned earlier, there is a normalization technique called 1 n f where if we're having multiple names in the, database table, then those names will be, divided into 2 separate table in order to,
# 18
# Okay, so so firstly I feel a fill up the form are using the platform unstop. So the this process takes four stages. So in in my first stage, I have to make sure that I have to make sure that my McQ question will be up to the mark so that I can qualify up to second round in second out that is coding assessment around so after coating after I clear coating assessment there is a data study around so in data study around I I find some difficulty because I have to collect that data which which is the requirement they provide as the topic. So whatever the requirement we have to collect the data and make our case study such that we can came to the we can so that I can I can came in the top three. So yeah. So the difficulties that case is still around itself.
# 19
# Hike in machine learning I know about the regularization technique like Labs on Rigid, but I am not sure about in generative way.
# 20
# the React JS, but then I yeah. So we, I used the encrypted I used, actually, API which were, in encrypting that link and sending us a resume. Again, even the password, we were encrypting that as well within, Google API. API. Yeah.
# 21
# so yeah, the evaluation part that I already told that we don't have right now and we really honestly don't have that in mind, but for the system requirements, I think the system is the systems are really are good. We have GPS we are we have a good number of CPUs and we have a good number of GPS to so for the system requirement. That won't be any issue. We have databases and also yeah 30 for this and it doesn't seem to have any show.
# 22
# Well python is an interpreted language so I can say that using some of the data data types, like dictionary lists tuples and other data variables. We can easily allocate the memory to the python interpreter. Where it is, it generates a dynamic memory whenever it whenever a data type or no. Whenever variable is implemented in it. So basically using a global and Diana malloc Dynamic processes. I can easily Implement my mother allocation, but
# 23
# I'm thinking of it right now, but, mainly,
# 24
# We I'm not, particularly, into low use of low adapters. Like, I just read the article where I've I saw that LoRa adapters is a a researcher published recently in one of the white papers that they claim that LoRa adapters can work better than LoRa for optimization, bigger foundation models like l lumps are stabilizations. I need to explore more about a lot of adapters, but that is one of our, future work which we plan to implement.
# 25
# Sure. Like, here are some, prioritized plan for implementing these future enhancements.
# 26
# No, I didn't. Deploy my app into production. It was just a testing app to Showcase my skills. On production level. Yes, you have to train it on a larger data set with a more computationally providing systems.
# 27
# I guess where in sci-fi the matrix multiplication and the
# 28

# %%
valid1s = res[(res["Valid"] == True) & (res["Label"] == 1)]
valid3s = res[(res["Valid"] == True) & (res["Label"] == 3)]
invalid1s = res[(res["Valid"] == False) & (res["Label"] == 1)]
invalid3s = res[(res["Valid"] == False) & (res["Label"] == 3)]
res.to_csv('../data/with_valid_classification.csv')

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import math
from tagger import Tagger

res = pd.read_csv('../data/with_valid_classification.csv')

valid_res = res[res["Valid"] == True]
invalid_res = res[res["Valid"] == False]

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(valid_res["Prediction"], bins=20, color='g', alpha=0.7)
plt.title('Distribution of Label Scores (Valid Responses)')
plt.xlabel('Label')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(invalid_res["Prediction"], bins=20, color='r', alpha=0.7)
plt.title('Distribution of Label Scores (Invalid Responses)')
plt.xlabel('Label')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# valid_1_and_2 = res[(res["Valid"] == True) & (res["Label"].isin([1, 2]))]
# valid_1_and_2.to_csv('../data/valid_1_and_2.csv')

# %%
# Load the valid_1_and_2 dataset
valid_1_and_2 = pd.read_csv('../data/valid_1_and_2.csv')

# Show rows that are misclassified
misclassified = valid_1_and_2[valid_1_and_2["Label"] != valid_1_and_2["Prediction"]]
misclassified
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 1               3             3             3           3
# 2               5             5             5           5
# 3               6             6             6           6
# 5              10            10            10          10
# 6              12            12            12          12
# ..            ...           ...           ...         ...
# 541           787           787           787         787
# 544           792           792           792         792
# 546           797           797           797         797
# 547           798           798           798         798
# 548           799           799           799         799
#
#                                             Input Text  Label  \
# 1    Interviewer: Training a Variational Autoencode...      2
# 2    Interviewer: It seems like you were about to p...      1
# 3    Interviewer: Great! I see from your applicatio...      1
# 5    Interviewer: Certainly. When you were incorpor...      1
# 6    Interviewer: Using JMeter for API load testing...      1
# ..                                                 ...    ...
# 541  Interviewer: Absolutely, recognizing and rewar...      2
# 544  Interviewer: Navigating the complexity of defi...      1
# 546  Interviewer: Please go ahead and outline the p...      2
# 547  Interviewer: Prioritizing frameworks with robu...      1
# 548  Interviewer: It's great that you experimented ...      2
#
#                                               Question  \
# 1    Training a Variational Autoencoder (VAE) to ge...
# 2    It seems like you were about to provide an exa...
# 3    Great! I see from your application that you ha...
# 5    Certainly. When you were incorporating recent ...
# 6    Using JMeter for API load testing is a solid a...
# ..                                                 ...
# 541  Absolutely, recognizing and rewarding contribu...
# 544  Navigating the complexity of defining routes, ...
# 546  Please go ahead and outline the prioritized pl...
# 547  Prioritizing frameworks with robust documentat...
# 548  It's great that you experimented with differen...
#
#                                               Response  Prediction  Valid
# 1    You could fit a gaussian mixture model to the ...           3   True
# 2                                    a custom callback           3   True
# 3    So I have worked on many projects where I have...           2   True
# 5    Actually at that time it was actually three ye...           2   True
# 6    So we have utilized the, APIs endpoints and, t...           2   True
# ..                                                 ...         ...    ...
# 541  He's always nice. Like it is always nice to ta...           3   True
# 544  A defining a defining a particular API route f...           2   True
# 546  Like, enhanced personalization, and there's a ...           3   True
# 547  So like whenever we have any error, like we ca...           2   True
# 548  Okay, so it in the Feature Part, it was the em...           3   True
#
# [330 rows x 10 columns]

# %%
valid_3_4_5 = res[(res["Label"].isin([3, 4, 5]))]
# valid_3_4_5.to_csv('../data/valid_3_4_5.csv')

# %%
valid_3_4_5 = pd.read_csv('../data/valid_3_4_5.csv')

valid_3_4_5[valid_3_4_5["Label"] != valid_3_4_5["Prediction"]]
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 1               2             2             2           2
# 11             60            60            60          60
# 15             77            77            77          77
# 16             84            84            84          84
# 17             87            87            87          87
# 19             95            95            95          95
# 21            103           103           103         103
# 22            104           104           104         104
# 28            164           164           164         164
# 32            188           188           188         188
# 33            195           195           195         195
# 37            212           212           212         212
# 38            213           213           213         213
# 39            217           217           217         217
# 40            222           222           222         222
# 41            240           240           240         240
# 42            241           241           241         241
# 43            252           252           252         252
# 44            268           268           268         268
# 47            282           282           282         282
# 49            302           302           302         302
# 50            308           308           308         308
# 51            316           316           316         316
# 54            328           328           328         328
# 57            350           350           350         350
# 58            353           353           353         353
# 59            359           359           359         359
# 60            363           363           363         363
# 62            371           371           371         371
# 67            417           417           417         417
# 68            439           439           439         439
# 70            445           445           445         445
# 76            503           503           503         503
# 77            509           509           509         509
# 78            518           518           518         518
# 84            535           535           535         535
# 85            540           540           540         540
# 86            558           558           558         558
# 92            585           585           585         585
# 95            603           603           603         603
# 96            607           607           607         607
# 97            611           611           611         611
# 99            623           623           623         623
# 100           625           625           625         625
# 101           628           628           628         628
# 102           632           632           632         632
# 104           641           641           641         641
# 105           643           643           643         643
# 108           651           651           651         651
# 111           669           669           669         669
# 116           712           712           712         712
# 118           735           735           735         735
# 120           753           753           753         753
# 121           759           759           759         759
# 122           763           763           763         763
# 123           773           773           773         773
# 124           781           781           781         781
# 128           796           796           796         796
#
#                                             Input Text  Label  \
# 1    Interviewer: That's a good approach to content...      4
# 11   Interviewer: Given your experience with optimi...      4
# 15   Interviewer: Using Truffle for testing and Myt...      3
# 16   Interviewer: Your approach to anomaly detectio...      4
# 17   Interviewer: It sounds like you've implemented...      4
# 19   Interviewer: What potential trade-offs or comp...      3
# 21   Interviewer: That's a comprehensive explanatio...      4
# 22   Interviewer: That's quite an impressive journe...      3
# 28   Interviewer: Given your experience with optimi...      4
# 32   Interviewer: Great! I see from your resume tha...      4
# 33   Interviewer: Those are some insightful challen...      4
# 37   Interviewer: That's a solid approach. Can you ...      3
# 38   Interviewer: Let's dive into the technical ski...      3
# 39   Interviewer: You've given a comprehensive over...      4
# 40   Interviewer: It sounds like you took a very me...      4
# 41   Interviewer: Great! I see from your resume tha...      4
# 42   Interviewer: That's a very interesting applica...      4
# 43   Interviewer: Great! Let's dive into the case s...      5
# 44   Interviewer: Understood, it's clear that your ...      3
# 47   Interviewer: Thank you for sharing those exper...      4
# 49   Interviewer: Great! I see from your resume tha...      4
# 50   Interviewer: It's clear that you have a strong...      4
# 51   Interviewer: Utilizing the Mahalanobis distanc...      4
# 54   Interviewer: Absolutely, please go ahead and c...      5
# 57   Interviewer: Great! I see from your resume tha...      3
# 58   Interviewer: Understood, it sounds like you we...      4
# 59   Interviewer: How do you approach the evaluatio...      3
# 60   Interviewer: Data augmentation is indeed a pow...      4
# 62   Interviewer: Understood, let's continue. Could...      4
# 67   Interviewer: Great! Let's dive into your resum...      4
# 68   Interviewer: Creating a custom metric that ali...      5
# 70   Interviewer: It's clear that Python has been a...      4
# 76   Interviewer: That's a comprehensive approach t...      3
# 77   Interviewer: Great! Can you tell me more about...      3
# 78   Interviewer: Implementing a streaming approach...      3
# 84   Interviewer: Certainly. I was asking about the...      4
# 85   Interviewer: Given the memory management chall...      3
# 86   Interviewer: Great! Let's start with your RHYM...      4
# 92   Interviewer: Understood, you've tailored your ...      4
# 95   Interviewer: Given the complexity of your mode...      4
# 96   Interviewer: Certainly! In Python, the "yield"...      3
# 97   Interviewer: Great! I see from your resume tha...      5
# 99   Interviewer: Of course. I see from your resume...      4
# 100  Interviewer: That's a very innovative approach...      4
# 101  Interviewer: It's great to hear that you have ...      4
# 102  Interviewer: That's a great application of Sea...      3
# 104  Interviewer: Could you now explain the concept...      4
# 105  Interviewer: I see, so the focus was on social...      4
# 108  Interviewer: Certainly, I can repeat the quest...      4
# 111  Interviewer: It's clear you've made significan...      4
# 116  Interviewer: That's a very interesting approac...      4
# 118  Interviewer: It's great to hear about your han...      4
# 120  Interviewer: That sounds like a solid high-lev...      4
# 121  Interviewer: Using Docker with FastAPI for mod...      4
# 122  Interviewer: Great! Let's dive into your resum...      3
# 123  Interviewer: I see, that's a crucial step for ...      3
# 124  Interviewer: Great! I see from your resume tha...      5
# 128  Interviewer: It's good to hear that you have h...      4
#
#                                               Question  \
# 1    That's a good approach to content filtering an...
# 11   Given your experience with optimizing models f...
# 15   Using Truffle for testing and MythX for securi...
# 16   Your approach to anomaly detection using ARIMA...
# 17   It sounds like you've implemented a straightfo...
# 19   What potential trade-offs or compromises might...
# 21   That's a comprehensive explanation, thank you....
# 22   That's quite an impressive journey from experi...
# 28   Given your experience with optimizing the Flas...
# 32   Great! I see from your resume that you've work...
# 33   Those are some insightful challenges you've id...
# 37   That's a solid approach. Can you dive into the...
# 38   Let's dive into the technical skills listed on...
# 39   You've given a comprehensive overview of how y...
# 40   It sounds like you took a very methodical appr...
# 41   Great! I see from your resume that you've led ...
# 42   That's a very interesting application of compu...
# 43   Great! Let's dive into the case study. Imagine...
# 44   Understood, it's clear that your experience wi...
# 47   Thank you for sharing those experiences. It's ...
# 49   Great! I see from your resume that you've work...
# 50   It's clear that you have a strong grasp on wor...
# 51   Utilizing the Mahalanobis distance and p-value...
# 54   Absolutely, please go ahead and complete your ...
# 57   Great! I see from your resume that you've comp...
# 58   Understood, it sounds like you were able to ma...
# 59   How do you approach the evaluation of model pe...
# 60   Data augmentation is indeed a powerful techniq...
# 62   Understood, let's continue. Could you explain ...
# 67   Great! Let's dive into your resume. I see you ...
# 68   Creating a custom metric that aligns with the ...
# 70   It's clear that Python has been a significant ...
# 76   That's a comprehensive approach to enhancing s...
# 77   Great! Can you tell me more about your experie...
# 78   Implementing a streaming approach and hosting ...
# 84   Certainly. I was asking about the challenges y...
# 85   Given the memory management challenges in Pyth...
# 86   Great! Let's start with your RHYM Threat Intel...
# 92   Understood, you've tailored your solution to t...
# 95   Given the complexity of your model and the nee...
# 96   Certainly! In Python, the "yield" keyword is u...
# 97   Great! I see from your resume that you've work...
# 99   Of course. I see from your resume that you've ...
# 100  That's a very innovative approach to enhancing...
# 101  It's great to hear that you have automated pro...
# 102  That's a great application of Seaborn to analy...
# 104  Could you now explain the concept of transfer ...
# 105  I see, so the focus was on social network algo...
# 108  Certainly, I can repeat the question. In the c...
# 111  It's clear you've made significant improvement...
# 116  That's a very interesting approach, leveraging...
# 118  It's great to hear about your hands-on experie...
# 120  That sounds like a solid high-level approach. ...
# 121  Using Docker with FastAPI for model deployment...
# 122  Great! Let's dive into your resume. I see you'...
# 123  I see, that's a crucial step for ensuring the ...
# 124  Great! I see from your resume that you've work...
# 128  It's good to hear that you have hands-on exper...
#
#                                               Response  Prediction  Valid
# 1    In web scraping, I have faced multiple challen...           3   True
# 11   So 11 text recognition was basically Made For ...           3   True
# 15   So basically when we did a static analysis wit...           2   True
# 16   Okay, so that is a very interesting question. ...           3   True
# 17   short transfer learning is a very common proce...           3   True
# 19   So first, I'll I'll work with a very small dum...           4   True
# 21   Right. So in this scenario, we incorporated a ...           3   True
# 22   Oh, yes. So this is small clarification here. ...           2   True
# 28   Okay. Um, so like there can be it's a very wid...           3   True
# 32   Okay. So one of the mid so basically Financial...           3   True
# 33   Okay. So, few things. So the thing is initiall...           3   True
# 37   So we had to define our own parameters and, me...           4   True
# 38   Okay. So as you read my, you know to like data...           2   True
# 39   yes, so over fitting is basically when you in ...           3   True
# 40   So I was working on graph convolution networks...           3   True
# 41   Oh, yeah. So first of all for the search of we...           3   True
# 42   Yes, so that is true. And for that initially h...           3   True
# 43   Okay. So the first thing okay. It's kind of ex...           3   True
# 44   Uh, yeah, so there are lots of times when and ...           2   True
# 47   Okay. Okay. So in that particular scenario, so...           3   True
# 49   Okay. So, starting from the beginning, So init...           3   True
# 50   Yeah, great question. So let's talk about one ...           3   True
# 51   So specifically we used heuristics from Financ...           3   True
# 54   Thank you, very good. So my second experiment ...           4   True
# 57   Here so basically use a python Library known a...           2   True
# 58   Yes. So reinforcement learning is something th...           3   True
# 59   It so the when evaluating mobile performance f...           2   True
# 60   I have always preferred pytorch, even though I...           3   True
# 62   So basically what we try to do is we try to Le...           3   True
# 67   Yes, sir. So I have I have found a pubg data s...           3   True
# 68   Okay. All right. So NLP something which I whic...           3   True
# 70   Yes, we have used a Java as well as python bas...           3   True
# 76   Up. So yeah, that's a good question. So again,...           2   True
# 77   Yeah. While the objective of my technical ende...           4   True
# 78   Um, yeah, I I have used AWS sagemaker. Actuall...           4   True
# 84   Yes, so number one. So when we have a plane fp...           3   True
# 85   It so there are two approaches to this. One of...           4   True
# 86   Okay, so for that we have Builder threat intel...           3   True
# 92   Are multiple projects in which I have applied ...           3   True
# 95   Here, so this project was actually funded by t...           3   True
# 96   Yes, so I said that I'm doing a project relate...           2   True
# 97   Sure, so the current problem that I faced doin...           4   True
# 99   Exactly. So in the NIT allahabad the research ...           3   True
# 100  Um depends on the you know resources I have so...           2   True
# 101  Shop, so firstly first and important the first...           3   True
# 102  Yeah first I've used the box plot SNS dot box ...           2   True
# 104  it Sure, so when it comes to transfer learning...           3   True
# 105  So the edge rank algorithm was like most more ...           3   True
# 108  Yes, so trade-off between a shallow and a deep...           3   True
# 111  Okay. Um, so because currently I'm working in ...           3   True
# 116  Okay. So the first thing is when we transition...           2   True
# 118  Exactly. So first of all, we have to do data a...           3   True
# 120  Okay. So one major challenge was that, the dat...           3   True
# 121  Shirt, so in this particular project the entir...           3   True
# 122  So first of all in my iot malware detection pr...           2   True
# 123  Yeah for forklift safety automation. We have u...           2   True
# 124  Up, right? So the models that I developed for ...           3   True
# 128  Yeah, great question. So the project that I wa...           3   True
